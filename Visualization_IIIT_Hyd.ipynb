),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(y,bins=20)
# Out:
# (array([ 1.,  3.,  0.,  3.,  0.,  9., 10.,  8., 12.,  8.,  7., 11., 11.,
#          4.,  4.,  3.,  3.,  0.,  1.,  2.]),
#  array([-2.37464398, -2.12130163, -1.86795928, -1.61461692, -1.36127457,
#         -1.10793222, -0.85458987, -0.60124752, -0.34790516, -0.09456281,
#          0.15877954,  0.41212189,  0.66546424,  0.91880659,  1.17214895,
#          1.4254913 ,  1.67883365,  1.932176  ,  2.18551835,  2.4388607 ,
#          2.69220306]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(x,bins=20,color='red')
# Out:
# (array([9., 1., 6., 5., 5., 3., 2., 9., 4., 6., 7., 6., 6., 4., 0., 4., 6.,
#         5., 4., 8.]),
#  array([9.40807688e-04, 5.05340506e-02, 1.00127294e-01, 1.49720536e-01,
#         1.99313779e-01, 2.48907022e-01, 2.98500265e-01, 3.48093508e-01,
#         3.97686751e-01, 4.47279994e-01, 4.96873237e-01, 5.46466480e-01,
#         5.96059723e-01, 6.45652966e-01, 6.95246209e-01, 7.44839451e-01,
#         7.94432694e-01, 8.44025937e-01, 8.93619180e-01, 9.43212423e-01,
#         9.92805666e-01]),
#  <BarContainer object of 20 artists>)

# %%
sns.histplot(y,bins=20, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.kdeplot(y,color="magenta",fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x,color="magenta",fill=True)
sns.kdeplot(y,color="blue",fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(1,2,1)
sns.kdeplot(x,color="magenta",fill=True)
plt.subplot(1,2,2)
sns.kdeplot(y,color="blue",fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
plt.subplot(2,1,1)
sns.kdeplot(x,color="magenta",fill=True)
plt.subplot(2,1,2)
sns.kdeplot(y,color="blue",fill=True)
# Out:
# <Axes: ylabel='Density'>

# %%
tips_df=sns.load_dataset('tips')

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
print(tips_df.head(10))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
print(tips_df.tail(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
print(tips_df.sample(10))
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 180       34.65  3.68    Male    Yes   Sun  Dinner     4
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 110       14.00  3.00    Male     No   Sat  Dinner     2
# 21        20.29  2.75  Female     No   Sat  Dinner     2
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3

# %%
tips_df.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips_df['time'].unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Lunch', 'Dinner']

# %%
sns.histplot(tips_df.total_bill,color='blue', bins=20)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(tips_df.tip,color='blue', bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips_df.tip/tips_df.total_bill)
# Out:
# <Axes: ylabel='Count'>

# %%
tips_df[tips_df.tip/tips_df.total_bill>0.5]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2

# %%
print(tips_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
days=tips_df.day.unique()
day_data={}
for  each_day in days:
      day_data[each_data]= [tips_df[tips_df['day']==each_day]['day'].count()]
prit(day_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-dbedbac04c25> in <cell line: 3>()
#       2 day_data={}
#       3 for  each_day in days:
# ----> 4       day_data[each_data]= [tips_df[tips_df['day']==each_day]['day'].count()]
#       5 prit(day_data)
#
# NameError: name 'each_data' is not defined

# %%
tips_df.groupby('day')['day'].count()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# Name: day, dtype: int64

# %%
tips_series=tips_df.groupby('day')['day'].count()
sns,barplot(x=tips_series.index,y=tips_series.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-c7c33dae4f04> in <cell line: 2>()
#       1 tips_series=tips_df.groupby('day')['day'].count()
# ----> 2 sns,barplot(x=tips_series.index,y=tips_series.values)
#
# NameError: name 'barplot' is not defined

# %%
tips_series=tips_df.groupby('sex')['day'].count()
sns.barplot(x=tips_series.index,y=tips_series.values)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.relplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.regplot(data=tips_df,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip')

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex')

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='day')

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex',col='smoker')

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex',row='sex')

# %%
sns.lmplot(data=tips_df[tips_df.sex=='male'],x='total_bill',y='tip')

# %%
sns.lmplot(data=tips_df[tips_df.sex=='female'],x='total_bill',y='tip')

# %%
sns.pairplot(tips_df)

# %% [markdown]
# Composition of Data

# %%
plt.pie(tips_series)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd88d2a0>,
#   <matplotlib.patches.Wedge at 0x7fa6fd88d120>],
#  [Text(-0.47909423581850497, 0.9901862012800839, ''),
#   Text(0.4790942358185044, -0.9901862012800842, '')])

# %%
plt.pie(tips_series,labels=tips_series.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd6671c0>,
#   <matplotlib.patches.Wedge at 0x7fa6fd6670d0>],
#  [Text(-0.47909423581850497, 0.9901862012800839, 'Male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'Female')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd9991b0>,
#   <matplotlib.patches.Wedge at 0x7fa6fd9990c0>],
#  [Text(-0.47909423581850497, 0.9901862012800839, 'Male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'Female')],
#  [Text(-0.2613241286282754, 0.5401015643345912, '64.34%'),
#   Text(0.2613241286282751, -0.5401015643345913, '35.66%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd8dff10>,
#   <matplotlib.patches.Wedge at 0x7fa6fd8dfe20>],
#  [Text(-0.47909423581850497, 0.9901862012800839, 'Male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'Female')],
#  [Text(-0.2613241286282754, 0.5401015643345912, '64.34%'),
#   Text(0.2613241286282751, -0.5401015643345913, '35.66%')])

# %% [markdown]
# Donut Chart

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,wedgeprops=dict(width=0.25))
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd2b6ce0>,
#   <matplotlib.patches.Wedge at 0x7fa6fd2b6bf0>],
#  [Text(-0.47909423581850497, 0.9901862012800839, 'Male'),
#   Text(0.4790942358185044, -0.9901862012800842, 'Female')],
#  [Text(-0.2613241286282754, 0.5401015643345912, '64.34%'),
#   Text(0.2613241286282751, -0.5401015643345913, '35.66%')])

# %%
plt.pie(tips_series,labels=tips_series.index,autopct='%0.2f%%',shadow=True,wedgeprops=dict(width=0.25),explode=[0,1])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa6fd32dfc0>,
#   <matplotlib.patches.Wedge at 0x7fa6fd32ded0>],
#  [Text(-0.47909423581850497, 0.9901862012800839, 'Male'),
#   Text(0.914634450198963, -1.8903554751710696, 'Female')],
#  [Text(-0.2613241286282754, 0.5401015643345912, '64.34%'),
#   Text(0.6968643430087336, -1.4402708382255769, '35.66%')])
